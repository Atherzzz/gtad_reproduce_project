# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/gtad-master/gtad_lib/
# Out:
# /content/gdrive/MyDrive/gtad-master/gtad_lib

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing Align1D.egg-info/PKG-INFO
# writing dependency_links to Align1D.egg-info/dependency_links.txt
# writing top-level names to Align1D.egg-info/top_level.txt
# /usr/local/lib/python3.7/dist-packages/torch/utils/cpp_extension.py:381: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'Align1D.egg-info/SOURCES.txt'
# writing manifest file 'Align1D.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-3.7/Align1D.cpython-37m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating stub loader for Align1D.cpython-37m-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/Align1D.py to Align1D.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying Align1D.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Align1D.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Align1D.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Align1D.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# __pycache__.Align1D.cpython-37: module references __file__
# creating 'dist/Align1D-2.2.0-py3.7-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing Align1D-2.2.0-py3.7-linux-x86_64.egg
# creating /usr/local/lib/python3.7/dist-packages/Align1D-2.2.0-py3.7-linux-x86_64.egg
# Extracting Align1D-2.2.0-py3.7-linux-x86_64.egg to /usr/local/lib/python3.7/dist-packages
# Adding Align1D 2.2.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/Align1D-2.2.0-py3.7-linux-x86_64.egg
# Processing dependencies for Align1D==2.2.0
# Finished processing dependencies for Align1D==2.2.0

# %%
# !python align.py
# Out:
# output has shape torch.Size([2, 2, 10]), with mean 8.550000190734863
# tensor([[[ 1.0000,  2.0000,  3.0000,  4.0000,  5.0000,  6.0000,  7.0000,
#            8.0000,  9.0000, 10.0000],
#          [11.0000, 12.0000, 13.0000, 14.0000, 15.0000, 16.0000, 17.0000,
#           18.0000, 19.0000, 20.0000]],
#
#         [[ 1.1500,  1.2500,  1.3500,  1.4500,  1.5500,  1.6500,  1.7500,
#            1.8500,  1.9500,  2.0500],
#          [11.1500, 11.2500, 11.3500, 11.4500, 11.5500, 11.6500, 11.7500,
#           11.8500, 11.9500, 12.0500]]], device='cuda:0')

# %%
cd ..
# Out:
# /content/gdrive/MyDrive/gtad-master

# %%
# !python dataset.py

# %%
# !python gtad_train.py
# Out:
# use 2 gpus to train!
# ./data/thumos_annotations/saved.2048.train.nf256.sf5.num200.train.pkl
# Got saved data.
# Size of data:  1697
# ./data/thumos_annotations/saved.2048.validation.nf256.sf5.num213.train.pkl
# Got saved data.
# Size of data:  1888
# gtad_train.py:125: UserWarning: Anomaly Detection has been enabled. This mode will increase the runtime and should only be enabled for debugging.
#   with autograd.detect_anomaly():
# [Epoch 000]	Loss 7.39 = 6.10 + 1.29 (train)
# [Epoch 000]	Loss 7.70 = 6.39 + 1.31 (validation)
# [Epoch 001]	Loss 6.57 = 5.34 + 1.23 (train)
# [Epoch 001]	Loss 6.92 = 5.63 + 1.29 (validation)
# [Epoch 002]	Loss 6.05 = 4.84 + 1.20 (train)
# [Epoch 002]	Loss 7.03 = 5.75 + 1.28 (validation)
# [Epoch 003]	Loss 5.64 = 4.45 + 1.19 (train)
# [Epoch 003]	Loss 6.77 = 5.50 + 1.27 (validation)
# [Epoch 004]	Loss 5.41 = 4.23 + 1.18 (train)
# [Epoch 004]	Loss 8.60 = 7.33 + 1.26 (validation)
# [Epoch 005]	Loss 4.86 = 3.69 + 1.17 (train)
# [Epoch 005]	Loss 7.22 = 5.96 + 1.26 (validation)
# [Epoch 006]	Loss 4.74 = 3.56 + 1.17 (train)
# [Epoch 006]	Loss 7.20 = 5.94 + 1.26 (validation)
# [Epoch 007]	Loss 4.65 = 3.48 + 1.17 (train)
# [Epoch 007]	Loss 7.22 = 5.96 + 1.26 (validation)
# [Epoch 008]	Loss 4.61 = 3.44 + 1.17 (train)
# [Epoch 008]	Loss 7.40 = 6.14 + 1.26 (validation)
# [Epoch 009]	Loss 4.53 = 3.37 + 1.16 (train)
# [Epoch 009]	Loss 7.52 = 6.26 + 1.26 (validation)

# %%
# !python gtad_inference.py
# Out:
# ./data/thumos_annotations/saved.2048.validation.nf256.sf5.num213.inference.pkl
# Got saved data.
# Size of data:  1925
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Inference start
# Inference finished

# %%
# !python gtad_postprocess.py
# Out:
# Detection post processing start
# Detection Post processing finished
# /content/gdrive/MyDrive/gtad-master/evaluation/utils_eval.py:53: RuntimeWarning: invalid value encountered in true_divide
#   tIoU = segments_intersection.astype(float) / segments_union
# /content/gdrive/MyDrive/gtad-master/evaluation/utils_eval.py:53: RuntimeWarning: invalid value encountered in true_divide
#   tIoU = segments_intersection.astype(float) / segments_union
# /content/gdrive/MyDrive/gtad-master/evaluation/utils_eval.py:53: RuntimeWarning: invalid value encountered in true_divide
#   tIoU = segments_intersection.astype(float) / segments_union
# /content/gdrive/MyDrive/gtad-master/evaluation/utils_eval.py:53: RuntimeWarning: invalid value encountered in true_divide
#   tIoU = segments_intersection.astype(float) / segments_union
# /content/gdrive/MyDrive/gtad-master/evaluation/utils_eval.py:53: RuntimeWarning: invalid value encountered in true_divide
#   tIoU = segments_intersection.astype(float) / segments_union
# /content/gdrive/MyDrive/gtad-master/evaluation/utils_eval.py:53: RuntimeWarning: invalid value encountered in true_divide
#   tIoU = segments_intersection.astype(float) / segments_union
# mAP at tIoU 0.3 is 0.08536972274604926
# mAP at tIoU 0.4 is 0.06892098040800823
# mAP at tIoU 0.5 is 0.04980800204816324
# mAP at tIoU 0.6 is 0.032569139119683364
# mAP at tIoU 0.7 is 0.018881980918547148

# %%
# !python models.py

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
